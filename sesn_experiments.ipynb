# %% [markdown]
# Code for SESN Paper

# %%
# !git clone https://github.com/spetrescu/sesn.git
# Out:
# Cloning into 'sesn'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 57 (delta 17), reused 41 (delta 9), pack-reused 0
# Unpacking objects: 100% (57/57), done.

# %%
# !ls
# Out:
# sample_data  sesn

# %%
# !pwd
# %cd sesn
# !ls
# Out:
# /content
# /content/sesn
# experiments_mnist.sh  models		      README.md		    utils
# experiments_stl.sh    prepare_datasets.py     train_scale_mnist.py  viz.gif
# LICENSE		      prepare_mnist_scale.sh  train_stl10.py

# %%
# !export MNIST_DIR=./datasets 
# !export MNIST_SCALE_DIR=./datasets
# !bash prepare_mnist_scale.sh
# Out:
# Preparing datasets...
#
# Dataset [1/6]
# source=./datasets
# dest=./datasets
# min_scale=0.3
# max_scale=1.0
# download=True
# seed=0
# validate=False
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:1315: UserWarning: Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead
#   "Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead"
# ...
# 9913344it [02:17, 72036.46it/s]
# Extracting ./datasets/MNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/raw
#
# ...
# 29696it [00:00, 1321009.81it/s]
# Extracting ./datasets/MNIST/raw/train-labels-idx1-ubyte.gz to ./datasets/MNIST/raw
#
# ...
# 1649664it [00:19, 84873.10it/s]
# Extracting ./datasets/MNIST/raw/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/raw
#
# ...
# 5120it [00:00, 21890760.94it/s]
# Extracting ./datasets/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/raw
#
# Processing...
# ...

# %%
# !bash experiments_mnist.sh
# Out:
# Args:
#   batch_size=128
#   epochs=60
#   optim=adam
#   momentum=0.9
#   nesterov=False
#   decay=0.0001
#   lr=0.01
#   lr_steps=[20, 40]
#   lr_gamma=0.1
#   model=mnist_ses_vector_56p
#   extra_scaling=1.0
#   cuda=True
#   save_model_path=./saved_models/mnist/mnist_ses_vector_56p_extra_scaling_1.0.pt
#   tag=sesn_experiments
#   data_dir=./datasets/MNIST_scale/seed_0/scale_0.3_1.0
#
# Train:
# ImageFolder Loader: num_workers=2, pin_memory=True, sampler=RandomSampler
# Root: ./datasets/MNIST_scale/seed_0/scale_0.3_1.0/train
# Data Points: 10000
#
# Transforms:
# Compose(
#     Grayscale(num_output_channels=1)
#     ToTensor()
#     Normalize(mean=(0.0607,), std=(0.2161,))
# )
#
# Val:
# ImageFolder Loader: num_workers=2, pin_memory=True, sampler=RandomSampler
# Root: ./datasets/MNIST_scale/seed_0/scale_0.3_1.0/val
# Data Points: 2000
#
# Transforms:
# Compose(
#     Grayscale(num_output_channels=1)
#     ToTensor()
#     Normalize(mean=(0.0607,), std=(0.2161,))
# )
#
# Test:
# ...
